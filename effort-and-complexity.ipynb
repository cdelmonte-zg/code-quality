# %% [markdown]
# ### Example of Efford and complexity analysis applied to the Spring Framework's Github repository###
# [https://github.com/spring-projects/spring-framework](https://github.com/spring-projects/spring-framework)

# %%
import pandas as pd

# %%
git_log = pd.read_csv('https://www.cdelmonte.de/wp-content/uploads/2019/11/effort_git-log_example.csv', names=["filepath"])

# %%
git_log.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 705 entries, 1319 to 25
# Data columns (total 1 columns):
# filepath    705 non-null object
# dtypes: object(1)
# memory usage: 11.0+ KB

# %%
git_log.head()
# Out:
#                                                filepath
# 1319                                       build.gradle
# 239                             src/asciidoc/index.adoc
# 187      build-spring-framework/resources/changelog.txt
# 171   spring-core/src/main/java/org/springframework/...
# 160   spring-beans/src/main/java/org/springframework...

# %%
top = git_log.filepath.value_counts().head(10)

# %%
# %matplotlib inline

# %%
top.plot.bar()

# %%
top.plot.pie();
